# %% [markdown]
# # Activity 18

# %% [markdown]
# ---
# ## Setup
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def prxgraddescent_l1(X,y,tau,lam,w_init,it):

## compute it iterations of L2 proximal gradient descent starting at w1
## w_{k+1}= (w_k - tau*X'*(X*w_k - y)/(1+lam*tau)
## step size tau
    W = np.zeros((w_init.shape[0], it+1))
    Z = np.zeros((w_init.shape[0], it+1))
    W[:,[0]] = w_init
    for k in range(it):
        Z[:,[k+1]] = W[:,[k]] - tau * X.T @ (X @ W[:,[k]] - y);
        W[:,[k+1]] = np.sign(Z[:,[k+1]])* np.clip(np.abs(Z[:,[k+1]])-lam*tau/2,0,float("inf"))
        
    return W,Z

# %%
## Proximal gradient descent trajectories
## Least Squares Problem
X = np.array([[2, 1]])
y = np.array([[4]])

### Find values of f(w), the contour plot surface for 
w1 = np.arange(-1,3,.1)
w2 = np.arange(-1,3,.1)
fw = np.zeros((len(w1), len(w2)))
for i in range(len(w2)):
    for j in range(len(w1)):
        w = np.array([ [w1[j]], [w2[i]] ])
        fw[i,j] = (X @ w - y)**2
# Out:
# C:\Users\Devin\AppData\Local\Temp\ipykernel_41580\3461163016.py:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   fw[i,j] = (X @ w - y)**2

# %% [markdown]
# ---
# ## Question 3a)
# ---

# %%
## Find and display weights generated by gradient descent

w_init = np.array([[0],[0]])
lam = 4;
it = 20
tau = 0.25
W,Z = prxgraddescent_l1(X,y,tau,lam,w_init,it)
# Concatenate gradient and regularization steps to display trajectory
G = np.zeros((2,0))
for i in range(it):
    G = np.hstack((G,np.hstack((W[:,[i]],Z[:,[i+1]]))))

plt.figure(figsize=(9,9))
plt.contour(w1,w2,fw,20)
plt.plot(Z[0,1::],Z[1,1:],'bx',linewidth=2, label="Gradient Descent Step")
plt.plot(W[0,:],W[1,:],'ro',linewidth=2, label="Regularization Step")
plt.plot(G[0,:],G[1,:],'-c',linewidth=2)
plt.legend()
plt.xlabel('w_1')
plt.ylabel('w_2')
plt.title('$\\tau = $'+str(.5)+', $\lambda = $'+str(lam));
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\l'
# <>:21: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\Devin\AppData\Local\Temp\ipykernel_41580\1970006614.py:21: SyntaxWarning: invalid escape sequence '\l'
#   plt.title('$\\tau = $'+str(.5)+', $\lambda = $'+str(lam));

# %%
W[:,-1]
# Out:
# array([1.5, 0. ])

# %%
# 3a comment: The algorithm takes 8 steps (counting both G-D steps and reg steps) to converge to a 
# point where it bounces back between a G-D and reg step to infinity.
# w_conv = [1.5, 0]

# %% [markdown]
# ---
# ## Question 3b)
# ---

# %%
## Find and display weights generated by gradient descent

w_init = np.array([[0],[0]])
lam = 2;
it = 20
tau = 0.25
W,Z = prxgraddescent_l1(X,y,tau,lam,w_init,it)
# Concatenate gradient and regularization steps to display trajectory
G = np.zeros((2,0))
for i in range(it):
    G = np.hstack((G,np.hstack((W[:,[i]],Z[:,[i+1]]))))

plt.figure(figsize=(9,9))
plt.contour(w1,w2,fw,20)
plt.plot(Z[0,1::],Z[1,1:],'bx',linewidth=2, label="Gradient Descent Step")
plt.plot(W[0,:],W[1,:],'ro',linewidth=2, label="Regularization Step")
plt.plot(G[0,:],G[1,:],'-c',linewidth=2)
plt.legend()
plt.xlabel('w_1')
plt.ylabel('w_2')
plt.title('$\\tau = $'+str(.5)+', $\lambda = $'+str(lam));
# Out:
# <>:21: SyntaxWarning: invalid escape sequence '\l'
# <>:21: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\Devin\AppData\Local\Temp\ipykernel_41580\552758031.py:21: SyntaxWarning: invalid escape sequence '\l'
#   plt.title('$\\tau = $'+str(.5)+', $\lambda = $'+str(lam));

# %%
W[:,-1]
# Out:
# array([1.75, 0.  ])

# %%
# Problem 3b comment:
# Now the algorithm takes 16 steps (total, defined the same way) before oscillating forever.
# w_conv = [1.75 0]

# %%
# Problem 3c comment:
# In the regularization step, the weights bounce back in the opposite direction. 
# They're pulled away from the path directly to the minimum solution.
